# %%
# Importation de la bibliothèque pandas
import pandas as pd

# %%
# Enregistrement du lien du fichier **Automobile_data.csc**
lien = "Automobile_data.csv"
# Création du dataset
df = pd.read_csv(lien)

# %%
#  affichage des 5 première ligne du fichier
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
# Affichage des n premières lignes du fichier
n = 10
df.head(n)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
# 5          2                 ?         audi       gas        std          two
# 6          1               158         audi       gas        std         four
# 7          1                 ?         audi       gas        std         four
# 8          1               158         audi       gas      turbo         four
# 9          0                 ?         audi       gas      turbo          two
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# ...

# %%
# Affichage des 5 dernières lignes du fichier
df.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 200      sedan          rwd           front       109.1  ...          141
# 201      sedan          rwd           front       109.1  ...          141
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# ...

# %%
# Affichage des n dernières lignes du fichier
n = 3
df.tail(n)
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 202      sedan          rwd           front       109.1  ...          173
# 203      sedan          rwd           front       109.1  ...          145
# 204      sedan          rwd           front       109.1  ...          141
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 202         mpfi  3.58    2.87               8.8        134      5500
# 203          idi  3.01     3.4              23.0        106      4800
# 204         mpfi  3.78    3.15               9.5        114      5400
#
#     city-mpg highway-mpg  price
# 202       18          23  21485
# ...

# %%
url = "car_data.csv"
data = pd.read_csv(url)

# %%
data.head()
# Out:
#    1235  taxi brousse  12  jaune  renault  renalt 19
# 0  1635     personnel  24   vert  peugeot        205
# 1  3105     transport  60  rouge  peogeot        205
# 2  5235     modele 12  30   rose  renault  renalt 24
# 3  1235  taxi brousse  12  jaune  renault  renalt 19
# 4  1635     personnel  24   vert  peugeot        205

# %%
# pour ignorer les entêtes 
data = pd.read_csv(url, header=None)

# %%
data.head()
# Out:
#       0             1   2      3        4          5
# 0  1235  taxi brousse  12  jaune  renault  renalt 19
# 1  1635     personnel  24   vert  peugeot        205
# 2  3105     transport  60  rouge  peogeot        205
# 3  5235     modele 12  30   rose  renault  renalt 24
# 4  1235  taxi brousse  12  jaune  renault  renalt 19

# %%
# Pour création d'une liste pour notre propre entête
headers = ["prix","category","duree","couleur","margue","modele"]

# %%
# Ajouter notre entête
data.columns=headers

# %%
data.head()
# Out:
#    prix      category  duree couleur   margue     modele
# 0  1235  taxi brousse     12   jaune  renault  renalt 19
# 1  1635     personnel     24    vert  peugeot        205
# 2  3105     transport     60   rouge  peogeot        205
# 3  5235     modele 12     30    rose  renault  renalt 24
# 4  1235  taxi brousse     12   jaune  renault  renalt 19

# %%
# exporter notre fichier CSV sous un autre format
df.to_json('car.json')

# %%
# from sqlalchemy import create_engine
# import pymysql
# pymysql.install_as_MySQLdb()
# # create_engine?
# engine = create_engine('mysql+mysqldb://root:@localhost:3306/test')
# df.to_sql(con=engine)
import mysql.connector
db_connection = mysql.connector.connect(
  host="localhost",
  database="test",
  port=3306,
  user="root",
  passwd=""
)

# %%
print(db_connection)
# db_connection??

# %%
data.describe(include="all")
# Out:
#                prix      category    duree couleur   margue modele
# count     24.000000            24  24.0000      24       24     24
# unique          NaN             4      NaN       4        3      3
# top             NaN  taxi brousse      NaN   rouge  renault    205
# freq            NaN             6      NaN       6       12     12
# mean    2802.500000           NaN  31.5000     NaN      NaN    NaN
# std     1601.250191           NaN  18.0651     NaN      NaN    NaN
# min     1235.000000           NaN  12.0000     NaN      NaN    NaN
# 25%     1535.000000           NaN  21.0000     NaN      NaN    NaN
# 50%     2370.000000           NaN  27.0000     NaN      NaN    NaN
# 75%     3637.500000           NaN  37.5000     NaN      NaN    NaN
# max     5235.000000           NaN  60.0000     NaN      NaN    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   prix      24 non-null     int64
#  1   category  24 non-null     object
#  2   duree     24 non-null     int64
#  3   couleur   24 non-null     object
#  4   margue    24 non-null     object
#  5   modele    24 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.2+ KB

# %%
l = data.describe(exclude='object')
type(l)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   prix      24 non-null     int64
#  1   category  24 non-null     object
#  2   duree     24 non-null     int64
#  3   couleur   24 non-null     object
#  4   margue    24 non-null     object
#  5   modele    24 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 1.2+ KB

# %%
data.describe()
# Out:
#               prix    duree
# count    24.000000  24.0000
# mean   2802.500000  31.5000
# std    1601.250191  18.0651
# min    1235.000000  12.0000
# 25%    1535.000000  21.0000
# 50%    2370.000000  27.0000
# 75%    3637.500000  37.5000
# max    5235.000000  60.0000
